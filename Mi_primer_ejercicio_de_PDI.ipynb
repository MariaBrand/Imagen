# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaBrand/Imagen/blob/master/Mi_primer_ejercicio_de_PDI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Se tiene que importar y luego inicializar la librería de Google drive. Para eso se escriben las siguientes dos lineas de codigo. Luego se va a la URL, se aceptan los terminos y condiciones y se copia/pega el codigo de autorización. Esto es para configurar el folder de imagenes de prueba.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Importar las librerias necesarias

import numpy as np
import matplotlib.pyplot as plt
import cv2

#Graficar imagenes estaticas en el notebook
# %matplotlib inline 
#Esta linea es para que me deje ver las graficas

# %% [markdown]
# Esta es la librería necesaria para leer y mostrar imagenes

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# Forma habitual de leer y mostrar una imagen (error en Colab)

# %%
image = cv2.imread('/content/drive/My Drive/PDI/IMG_0393.JPG')
cv2.imshow("Image", image)
cv2.waitKey(0)

# %% [markdown]
# Esta es la forma correcta de leer y mostrar una imagen (Además de las dos lineas de abajo se debe importar la librería de cv2_imshow que está más arriba)

# %%
img = cv2.imread('/content/drive/My Drive/PDI/IMG_0393.JPG', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x960 at 0x7F90DB2563C8>

# %% [markdown]
# Cambiar rutas de folders y archivos opción 1
# Cambiar tamaño para no escribir toda la dirección, solo el nombre de la imagen

# %%
# !pwd
# !ls
#%cd ../
# %cd /content/drive/My Drive/PDI/
# !pwd

from google.colab.patches import  cv2_imshow
img = cv2.imread('IMG_0298.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int (300), int(300)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/PDI
# IMG_0298.jpg  IMG_0393.JPG
# /content/drive/My Drive/PDI
# /content/drive/My Drive/PDI
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F90D91A7550>

# %% [markdown]
# Importar la misma imagen anterior pero utilizando solo Phyton

# %%
import os
path = '/content/drive/My Drive/PDI/' #Recordar que se debe inicializar (dar play) la librería que accede a Drive (Linea 1)
os.chdir(path)
# !pwd

from google.colab.patches import cv2_imshow #Lo mismo, inicializarlo más arriba siempre
img = cv2.imread('IMG_0393.JPG', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(300), int (300)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/PDI
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F9950C509B0>

# %% [markdown]
# Leer una imagen usando la libreria matplotlib inicializada arriba como plt

# %%
#plt = principle of least astonishment
#cv2 lee la imagen la lee en BGR, nosotros despues de la transformacion podemos cambiar la imagen a RGB 

img_BGR = cv2.imread('IMG_0393.JPG', cv2.IMREAD_COLOR)

plt.figure(figsize=(7,7)) #Crear frame, aqui se transfroma en un sandwich, despues de esta linea configuramos hasta el .show()
plt.imshow(img_BGR)
#Para poder ver la imagen
plt.show()
